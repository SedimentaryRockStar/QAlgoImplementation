# %%
# Do the necessary imports
import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit import IBMQ, Aer, transpile, assemble
from qiskit.visualization import plot_histogram, plot_bloch_multivector, array_to_latex
from qiskit.extensions import Initialize
from qiskit.ignis.verification import marginal_counts
from qiskit.quantum_info import random_statevector
# Out:
# /tmp/ipykernel_521/2604430877.py:7: DeprecationWarning: The qiskit.ignis package is deprecated and has been supersceded by the qiskit-experiments project. Refer to the migration guide: https://github.com/Qiskit/qiskit-ignis#migration-guide on how to migrate to the new project.
#   from qiskit.ignis.verification import marginal_counts

# %%
qc= QuantumCircuit(3, 2)

psi = random_statevector(2)
display(array_to_latex(psi, prefix="|\\psi\\rangle ="))
plot_bloch_multivector(psi)
# Out:
# $$
# |\psi\rangle =
# \begin{bmatrix}
# 0.64509 + 0.22805i & 0.24563 + 0.68667i  \\
#  \end{bmatrix}
# $$

# %%
init_gate = Initialize(psi)
qc.append(init_gate, [0])
qc.barrier()

qc.h(1)
qc.cx(1, 2)
qc.barrier() #Use Physical barrier to separate the steps
qc.cx(0, 1)
qc.h(0)
qc.barrier()
qc.cx(1, 2)
qc.cz(0, 2)
qc.draw(output= "mpl")

# %%
sim = Aer.get_backend('aer_simulator')
qc.save_statevector()
out_vector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(out_vector)

# %%
psi = random_statevector(2)
display(array_to_latex(psi, prefix="|\\psi\\rangle ="))
plot_bloch_multivector(psi)
# Out:
# $$
# |\psi\rangle =
# \begin{bmatrix}
# -0.69363 + 0.25261i & 0.54788 + 0.39357i  \\
#  \end{bmatrix}
# $$
